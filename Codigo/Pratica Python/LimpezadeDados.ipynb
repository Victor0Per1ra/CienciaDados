# %%
import pandas as pd

# %%
dados = pd.read_csv('Bases/Credit.csv')
dados.head(1)
# Out:
#   checking_status  duration                    credit_history   purpose  \
# 0              <0         6  'critical/other existing credit'  radio/tv
#
#    credit_amount      savings_status employment  installment_commitment  \
# 0           1169  'no known savings'        >=7                       4
#
#   personal_status other_parties  ...  property_magnitude age  \
# 0   'male single'          none  ...       'real estate'  67
#
#    other_payment_plans housing existing_credits      job num_dependents  \
# 0                 none     own                2  skilled              1
#
#    own_telephone foreign_worker class
# 0            yes            yes  good
#
# [1 rows x 21 columns]

# %%
#se existe dados nulos
dados.isnull()
# Out:
#      checking_status  duration  credit_history  purpose  credit_amount  \
# 0              False     False           False    False          False
# 1              False     False           False    False          False
# 2              False     False           False    False          False
# 3              False     False           False    False          False
# 4              False     False           False    False          False
# ..               ...       ...             ...      ...            ...
# 995            False     False           False    False          False
# 996            False     False           False    False          False
# 997            False     False           False    False          False
# 998            False     False           False    False          False
# 999            False     False           False    False          False
#
#      savings_status  employment  installment_commitment  personal_status  \
# ...

# %%
#outro jeito de verificar
##Ele vê quantos dados nulos tem por coluna
dados.isnull().sum()
# Out:
# checking_status           0
# duration                  0
# credit_history            0
# purpose                   0
# credit_amount             0
# savings_status            0
# employment                0
# installment_commitment    0
# personal_status           0
# other_parties             0
# residence_since           0
# property_magnitude        0
# age                       0
# other_payment_plans       0
# housing                   0
# existing_credits          0
# job                       0
# num_dependents            0
# own_telephone             0
# foreign_worker            0
# class                     0
# dtype: int64

# %%
#quando queremos preencher um dados que está faltando, um case de sql, por exemplo 
dados['duration'].fillna(0,inplace = True)
#Aqui ele vai preencher as informações que estão NA com o valor de 0, como não tem NA, ele não faz nada

# %%
##Ele vê quantos dados nulos tem por coluna
exemplo = dados[['class']].loc[dados['credit_amount']==1169]
print(exemplo)
# Out:
#     class
# 0    good
# 894  good
